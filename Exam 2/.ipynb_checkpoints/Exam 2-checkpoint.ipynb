# %% [markdown]
# # Exam 2
# ## ATSC 270 - Computer Concepts in Meteorology
#
# This notebook downloads sounding data from the Iowa Environmental Mesonet (IEM) archive and plots the sounding on a Skew-T Log-P diagram.
#
# The notebook does not work correctly.  Your exam is to go through the following code and fix any bugs.  Note, this code may include <i><b>logical errors</b></i> - or errors in the logic of the code.  The code may run, but provide incorrect output.  This includes incorrect unit conversions.

# %%
#import required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from metpy.io import metar
import metpy.calc as mpcalc
from metpy.plots import Hodograph, SkewT
from metpy.units import units

from datetime import datetime

# %%
# date, time and station of sounding to be plotted
year = 2011
month = 4
day = 27
hour = 18

station = "KJAN"

# %% [markdown]
# ### Get Sounding Data from the Iowa Environmental Mesonet (IEM) RAOB Archive
# <u>There will be no errors in this section</u>

# %%
#get data from Iowa Environmental Mesonet (IEM) RAOB archive
filename = 'KJAN_2011042718_2011042718(2).txt'
data = pd.read_csv('KJAN_2011042718_2011042718(2).txt',delimiter=',')
#print(data)
#convert date and time to datetime object
dt = datetime(year=year,month=month,day=day,hour=hour)

#convert datetime object to string to add into the IEM url
t = dt.strftime('%Y%m%d%H%M')

#define the url
url = f"https://mesonet.agron.iastate.edu/json/raob.py?ts={t}&station={station}"

#read the json sounding data using pandas
json = pd.read_json(url)

#convert the json sounding to a pandas dataframe
df = pd.json_normalize(json.profiles[0],'profile',['station','valid'])

#convert the "valid" variable to a datetime object
df['valid'] = pd.to_datetime(df['valid'])
print(df)
# Out:
#        pres     hght  tmpc  dwpc   drct  sknt station  \
# 0    1000.0      8.0   NaN   NaN    NaN   NaN    KJAN
# 1     991.0     91.0  27.8  21.8  170.0  10.0    KJAN
# 2     988.0    118.0  27.2  22.2    NaN   NaN    KJAN
# 3     967.2    304.0   NaN   NaN  205.0  39.0    KJAN
# 4     960.0    369.0  24.8  20.1    NaN   NaN    KJAN
# ..      ...      ...   ...   ...    ...   ...     ...
# 123    10.4  30678.0 -42.7 -71.7    NaN   NaN    KJAN
# 124    10.1  30876.0 -39.7 -66.7    NaN   NaN    KJAN
# 125    10.0  30960.0 -38.9 -66.9  265.0  31.0    KJAN
# 126     9.8  31089.0   NaN   NaN  275.0  31.0    KJAN
# 127     9.7  31168.0 -38.7 -66.7    NaN   NaN    KJAN
#
#                         valid
# 0   2011-04-27 18:00:00+00:00
# 1   2011-04-27 18:00:00+00:00
# 2   2011-04-27 18:00:00+00:00
# 3   2011-04-27 18:00:00+00:00
# 4   2011-04-27 18:00:00+00:00
# ..                        ...
# 123 2011-04-27 18:00:00+00:00
# 124 2011-04-27 18:00:00+00:00
# 125 2011-04-27 18:00:00+00:00
# 126 2011-04-27 18:00:00+00:00
# 127 2011-04-27 18:00:00+00:00
#
# [128 rows x 8 columns]

# %% [markdown]
# ### Get Dataframe Ready for Plotting

# %%
### create a new dataframe for just temperature and dewpoint ###
df_temp = pd.DataFrame()
#first remove any rows where there is no data
df_temp = df.dropna(subset=['tmpc','dwpc'])
#next just keep pressure, height, temperature, and dewpoint
df_temp = df_temp[['pres','hght','tmpc','dwpc']]

### create a new dataframe for just winds ###
#first remove any rows where there is no data
df_wind = df.dropna(subset=['sknt','drct'])
#next just keep pressure, height, temperature, and dewpoint
'''df_wind = df_temp[['pres','hght','tmpc','dwpc']]'''
print(df_wind)
# Out:
#       pres     hght  tmpc  dwpc   drct  sknt station                     valid
# 1    991.0     91.0  27.8  21.8  170.0  10.0    KJAN 2011-04-27 18:00:00+00:00
# 3    967.2    304.0   NaN   NaN  205.0  39.0    KJAN 2011-04-27 18:00:00+00:00
# 5    933.7    609.0   NaN   NaN  200.0  40.0    KJAN 2011-04-27 18:00:00+00:00
# 7    925.0    695.0  21.8  20.3  200.0  42.0    KJAN 2011-04-27 18:00:00+00:00
# 8    901.6    914.0   NaN   NaN  200.0  42.0    KJAN 2011-04-27 18:00:00+00:00
# 11   870.1   1219.0   NaN   NaN  215.0  54.0    KJAN 2011-04-27 18:00:00+00:00
# 14   850.0   1426.0  16.8  15.3  220.0  54.0    KJAN 2011-04-27 18:00:00+00:00
# 15   840.1   1524.0   NaN   NaN  220.0  56.0    KJAN 2011-04-27 18:00:00+00:00
# 16   810.3   1828.0   NaN   NaN  225.0  55.0    KJAN 2011-04-27 18:00:00+00:00
# 20   781.3   2133.0   NaN   NaN  225.0  58.0    KJAN 2011-04-27 18:00:00+00:00
# 23   753.4   2438.0   NaN   NaN  225.0  58.0    KJAN 2011-04-27 18:00:00+00:00
# 24   726.6   2743.0   NaN   NaN  225.0  57.0    KJAN 2011-04-27 18:00:00+00:00
# 25   700.0   3056.0   7.0   2.0  230.0  57.0    KJAN 2011-04-27 18:00:00+00:00
# 30   650.3   3657.0   NaN   NaN  230.0  68.0    KJAN 2011-04-27 18:00:00+00:00
# 33   602.8   4267.0   NaN   NaN  230.0  73.0    KJAN 2011-04-27 18:00:00+00:00
# 36   558.2   4876.0   NaN   NaN  240.0  68.0    KJAN 2011-04-27 18:00:00+00:00
# 40   500.0   5740.0  -9.7 -33.7  250.0  74.0    KJAN 2011-04-27 18:00:00+00:00
# 42   477.0   6096.0   NaN   NaN  250.0  75.0    KJAN 2011-04-27 18:00:00+00:00
# 43   400.0   7420.0 -22.7 -46.7  250.0  80.0    KJAN 2011-04-27 18:00:00+00:00
# 44   389.0   7620.0   NaN   NaN  250.0  79.0    KJAN 2011-04-27 18:00:00+00:00
# 111   21.4  25908.0   NaN   NaN   25.0   1.0    KJAN 2011-04-27 18:00:00+00:00
# 112   20.0  26340.0 -53.1 -75.1  140.0   8.0    KJAN 2011-04-27 18:00:00+00:00
# 113   19.5  26517.0   NaN   NaN  175.0  14.0    KJAN 2011-04-27 18:00:00+00:00
# 115   17.7  27127.0   NaN   NaN  190.0   5.0    KJAN 2011-04-27 18:00:00+00:00
# 116   16.9  27432.0   NaN   NaN  180.0  11.0    KJAN 2011-04-27 18:00:00+00:00
# 117   16.1  27736.0   NaN   NaN  215.0  14.0    KJAN 2011-04-27 18:00:00+00:00
# 119   15.4  28041.0   NaN   NaN  280.0  26.0    KJAN 2011-04-27 18:00:00+00:00
# 122   10.7  30480.0   NaN   NaN  290.0  29.0    KJAN 2011-04-27 18:00:00+00:00
# 125   10.0  30960.0 -38.9 -66.9  265.0  31.0    KJAN 2011-04-27 18:00:00+00:00
# 126    9.8  31089.0   NaN   NaN  275.0  31.0    KJAN 2011-04-27 18:00:00+00:00

# %% [markdown]
# ### Create Numpy Arrays for Temperature Plotting and Add Units

# %%
pressure = np.array(df_temp['pres']) * units('millibars')
height = np.array(df_temp['hght']) * units('meters')
temperature = np.array(df_temp['tmpc']) * units('degF')
dewpoint = np.array(df_temp['dwpc']) * units('degF')

# %% [markdown]
# ### Create Numpy Arrays for Wind Plotting and Add Units

# %%
wind_pressure = np.array(df_wind['pres']) * units('millibars')
wind_height = np.array(df_wind['hght']) * units('meters')
wind_speed = np.array(df_wind['sknt']) * units('knots')
wind_direction = np.array(df_wind['drct']) * units('degrees')

# %% [markdown]
# ### Convert Wind Speed & Direction to U & V

# %%
u,v = mpcalc.wind_components(wind_speed, wind_direction)

# %% [markdown]
# ### Make Figure

# %%
#create skew-t figure
fig = plt.figure(figsize=(11, 8), dpi=100,facecolor='w')
skew = SkewT(fig, rotation=45)


#plot temperature in red and dewpoint in green
skew.plot(pressure, temperature, 'r',lw=3)
skew.plot(pressure, dewpoint, 'g',lw=3)

#create axes labels
plt.xlabel('TEMPERATURE ($^\circ$C)',fontsize=15)
plt.ylabel('PRESSURE (mb)',fontsize=15)

#add in typical lines
skew.plot_dry_adiabats()
skew.plot_moist_adiabats()
skew.plot_mixing_lines()

#plot winds 
#only plot every other wind barb so it's not too busy
#(y_clip_radius keeps barbs from plotting outside of skew-t)
skew.plot_barbs(wind_pressure[::2], u[::2], v[::2], y_clip_radius=0)
#add title for date and location
plt.title(f'{station}\n%04i-%02i-%02i %02iZ'%(year,month,day,hour), fontsize=15)

#save figure
fig.tight_layout()
plt.savefig(f'{station}_%04i%02i%02i_%02i.png'%(year,month,day,hour))
